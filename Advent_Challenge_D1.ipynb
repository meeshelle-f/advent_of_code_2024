# %% [markdown]
# #Day 1 Part 1
# inputs = day1_input.txt

# %%
file_path = '/content/drive/MyDrive/Advent 2024/day1/input.txt'

# with open(file_path, 'r') as f:
#     text = f.read()
# print(text)

df = pd.read_csv(file_path, delimiter='  ', header=None,engine='python')  # Use appropriate delimiter
# df
# Out:
#          0      1
# 0    28186  35627
# 1    51854  34597
# 2    19211  51032
# 3    79370  53096
# 4    68126  40302
# ..     ...    ...
# 995  52402  40046
# 996  78358  41164
# 997  83450  76669
# 998  62947  25771
# 999  55820  53096
#
# [1000 rows x 2 columns]

# %%
import numpy as np
import pandas as pd


def replace_non_integers_with_zero(df):
  """Replaces non-integer values in a DataFrame with 0.

  Args:
    df: The input DataFrame.

  Returns:
    The DataFrame with non-integer values replaced by 0.
  """

  for col in df.columns:
    df[col] = df[col].apply(lambda x: 0 if not isinstance(x, (int, np.integer)) else x)

  return df

df = replace_non_integers_with_zero(df)
df
# Out:
#          0      1
# 0    28186  35627
# 1    51854  34597
# 2    19211  51032
# 3    79370  53096
# 4    68126  40302
# ..     ...    ...
# 995  52402  40046
# 996  78358  41164
# 997  83450  76669
# 998  62947  25771
# 999  55820  53096
#
# [1000 rows x 2 columns]

# %%
# # Sample DataFrame with mixed data types
# data = {'col1': [1, 2, 'a', 4],
#         'col2': [5.0, 6, 7, 'b']}
# df = pd.DataFrame(data)

# data = {'col1': [3,4,2,1,3,3],
#         'col2': [4,3,5,3,9,3]}
# df = pd.DataFrame(data)



# Replace non-integer values with 0
df = replace_non_integers_with_zero(df)

for col in df.columns:
  df[col] = sorted(list(df[col]))

df
# Out:
#          0      1
# 0    10004  10010
# 1    10484  10083
# 2    10539  10303
# 3    10609  10537
# 4    10721  10899
# ..     ...    ...
# 995  99765  99650
# 996  99826  99650
# 997  99876  99650
# 998  99885  99650
# 999  99974  99689
#
# [1000 rows x 2 columns]

# %%
list(df.columns)
diff = abs(df[list(df.columns)[0]] - df[list(df.columns)[1]])
total_abs_diff = diff.sum()
total_abs_diff
# Out:
# 11

# %% [markdown]
# #Part 2

# %%
df
# Out:
#          0      1
# 0    10004  10010
# 1    10484  10083
# 2    10539  10303
# 3    10609  10537
# 4    10721  10899
# ..     ...    ...
# 995  99765  99650
# 996  99826  99650
# 997  99876  99650
# 998  99885  99650
# 999  99974  99689
#
# [1000 rows x 2 columns]

# %%
from collections import Counter

# Count occurrences of all values in the list
value_counts = Counter(list(df[1]))
print(value_counts)  # Output: Counter({1: 3, 2: 2, 3: 2, 4: 1, 5: 1})
# Out:
# Counter({53096: 20, 60776: 20, 76669: 20, 67595: 19, 83450: 19, 99650: 19, 25771: 18, 33493: 17, 14411: 16, 31838: 16, 61946: 16, 39216: 15, 56652: 15, 22021: 14, 78358: 14, 13764: 13, 91017: 13, 54622: 12, 94225: 12, 18285: 11, 73961: 11, 84304: 11, 45165: 10, 53077: 10, 54600: 10, 40165: 9, 54490: 8, 56578: 8, 35627: 7, 91386: 7, 35817: 6, 64811: 6, 82383: 6, 63046: 5, 28916: 4, 36264: 4, 76838: 4, 64910: 3, 71764: 3, 53851: 2, 54586: 2, 10010: 1, 10083: 1, 10303: 1, 10537: 1, 10899: 1, 11086: 1, 11111: 1, 11171: 1, 11314: 1, 11666: 1, 12104: 1, 12578: 1, 12822: 1, 12889: 1, 12978: 1, 13061: 1, 13231: 1, 13301: 1, 13454: 1, 13557: 1, 13761: 1, 13782: 1, 13804: 1, 14088: 1, 14301: 1, 14353: 1, 14704: 1, 14964: 1, 15028: 1, 15067: 1, 15111: 1, 15169: 1, 15327: 1, 15765: 1, 16181: 1, 16295: 1, 16393: 1, 16412: 1, 16837: 1, 17039: 1, 17094: 1, 17250: 1, 17312: 1, 17554: 1, 17587: 1, 18197: 1, 18292: 1, 18344: 1, 18455: 1, 18579: 1, 18724: 1, 18807: 1, 18897: 1, 18998: 1, 19177: 1, 1930
# ...

# %%
value_sums = 0
for key in list(df[0]):
  if key in value_counts.keys():
    value_sums += (key * value_counts[key])
    # print(key,value_counts[key],value_sums )
print(value_sums) #25574739
# Out:
# 25574739
